# %%
import numpy as np
import sklearn as sk
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as img
import os
import cv2 as cv

# %%
testImage=img.imread('../flowers/artichoke/344.jpeg')
plt.imshow(testImage)

# %%
data=[]
label=[]
FlowerPath='../flowers/'
os.listdir(FlowerPath)
for folder in os.listdir(FlowerPath):
    for file in os.listdir(os.path.join(FlowerPath, folder)):
        if file.endswith("jpeg"):
            label.append(folder)
            img = cv.imread(os.path.join(FlowerPath, folder, file))
            img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
            im = cv.resize(img_rgb, (512,512))
            data.append(im)
        else:
            continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3032/2540729894.py in <module>
#       7         if file.endswith("jpeg"):
#       8             label.append(folder)
# ----> 9             img = cv.imread(os.path.join(FlowerPath, folder, file))
#      10             img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
#      11             im = cv.resize(img_rgb, (512,512))
#
# KeyboardInterrupt:

# %%
img2 = cv.cvtColor(testImage,cv.COLOR_BGR2RGB)
red,green,blue = cv.split(img2)
plt.subplot(131)
plt.imshow(red,cmap=cm.gray)
plt.subplot(132)
plt.imshow(green,cmap=cm.gray)
plt.subplot(133)
plt.imshow(blue,cmap=cm.gray)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3032/1210550761.py in <module>
#       2 red,green,blue = cv.split(img2)
#       3 plt.subplot(131)
# ----> 4 plt.imshow(red,cmap=cm.gray)
#       5 plt.subplot(132)
#       6 plt.imshow(green,cmap=cm.gray)
#
# NameError: name 'cm' is not defined
